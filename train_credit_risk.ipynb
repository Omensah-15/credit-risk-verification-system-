# %%
# Import Libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Machine Learning
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, RobustScaler
from sklearn.metrics import (roc_auc_score, accuracy_score, f1_score, precision_score, 
                            recall_score, classification_report, confusion_matrix,
                            roc_curve, precision_recall_curve)
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import (RandomForestClassifier, GradientBoostingClassifier, 
                             VotingClassifier, StackingClassifier)
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

# Handling Imbalanced Data
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.combine import SMOTETomek

# XGBoost and LightGBM
import xgboost as xgb
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation

# Hyperparameter Optimization
import optuna
from optuna.samplers import TPESampler

# Utilities
import joblib
from datetime import datetime

# Set style for better visualizations
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("All libraries imported successfully")
# Out:
# All libraries imported successfully

# %%
# Configuration and Settings
class Config:
    # Paths
    DATA_DIR = "data"
    MODELS_DIR = "models"
    REPORTS_DIR = "reports"
    FIGS_DIR = "figures"
    
    # Random seed for reproducibility
    RANDOM_STATE = 42
    np.random.seed(RANDOM_STATE)
    
    # Data settings
    TEST_SIZE = 0.2
    VAL_SIZE = 0.2
    
    # Model settings
    CV_FOLDS = 5
    N_TRIALS = 50
    N_JOBS = -1
    
    # Create directories
    for dir_path in [DATA_DIR, MODELS_DIR, REPORTS_DIR, FIGS_DIR]:
        os.makedirs(dir_path, exist_ok=True)

config = Config()
print(f"Configuration initialized")
print(f"Models will be saved to: {config.MODELS_DIR}")
# Out:
# Configuration initialized
# Models will be saved to: models

# %%
# Create Dataset with Specified Columns Only
def create_dataset_with_specified_columns(n_samples=20000):
    """
    Create dataset using only the columns specified in the image
    """
    np.random.seed(config.RANDOM_STATE)
    
    # Applicant Fields
    customer_id = [f'CUST{str(i).zfill(6)}' for i in range(1, n_samples + 1)]
    
    # Age with realistic distribution
    age = np.random.normal(42, 12, n_samples).astype(int)
    age = np.clip(age, 18, 80)
    
    # Employment status
    employment_status = np.random.choice(
        ['Employed', 'Self-Employed', 'Unemployed', 'Retired', 'Student'],
        n_samples,
        p=[0.58, 0.15, 0.08, 0.12, 0.07]
    )
    
    # Education level
    education_level = np.random.choice(
        ['High School', 'Diploma', 'Bachelor', 'Master', 'PhD'],
        n_samples,
        p=[0.20, 0.25, 0.35, 0.15, 0.05]
    )
    
    # Financial Fields
    annual_income = np.random.lognormal(mean=10.8, sigma=0.5, size=n_samples).astype(int)
    annual_income = np.clip(annual_income, 20000, 300000)
    
    num_previous_loans = np.random.negative_binomial(n=2, p=0.4, size=n_samples)
    num_previous_loans = np.clip(num_previous_loans, 0, 15)
    
    avg_payment_delay_days = np.random.exponential(scale=8, size=n_samples).astype(int)
    avg_payment_delay_days = np.clip(avg_payment_delay_days, 0, 90)
    
    # Credit History
    credit_history_length = np.random.gamma(shape=3, scale=2, size=n_samples).astype(int)
    credit_history_length = np.clip(credit_history_length, 1, 30)
    
    num_defaults_base = np.random.poisson(lam=0.4, size=n_samples)
    num_defaults = np.where(employment_status == 'Unemployed', 
                           num_defaults_base + np.random.poisson(0.3, n_samples),
                           num_defaults_base)
    num_defaults = np.clip(num_defaults, 0, 4)
    
    # Current credit score (strongly correlated with history and defaults)
    base_score = 600 + 10 * credit_history_length - 40 * num_defaults
    current_credit_score = np.random.normal(base_score, 35).astype(int)
    current_credit_score = np.clip(current_credit_score, 350, 850)
    
    # Loan Parameters
    loan_amount = np.random.lognormal(mean=10.2, sigma=0.7, size=n_samples).astype(int)
    loan_amount = np.clip(loan_amount, 1000, 150000)
    
    loan_term_months = np.random.choice([12, 24, 36, 48, 60, 72], n_samples, 
                                       p=[0.10, 0.15, 0.30, 0.20, 0.15, 0.10])
    
    loan_purpose = np.random.choice(
        ['Business', 'Crypto-Backed', 'Car Loan', 'Education', 'Home Loan'],
        n_samples,
        p=[0.25, 0.15, 0.30, 0.15, 0.15]
    )
    
    # Collateral
    collateral_present = np.random.choice(['Yes', 'No'], n_samples, p=[0.45, 0.55])
    
    # Create dataframe with exactly the columns from the image
    df = pd.DataFrame({
        'customer_id': customer_id,
        'age': age,
        'employment_status': employment_status,
        'education_level': education_level,
        'annual_income': annual_income,
        'num_previous_loans': num_previous_loans,
        'avg_payment_delay_days': avg_payment_delay_days,
        'credit_history_length': credit_history_length,
        'num_defaults': num_defaults,
        'current_credit_score': current_credit_score,
        'loan_amount': loan_amount,
        'loan_term_months': loan_term_months,
        'loan_purpose': loan_purpose,
        'collateral_present': collateral_present
    })
    
    # Generate target with complex interactions
    risk_score = np.zeros(n_samples)
    
    # Key risk factors
    risk_score += (df['current_credit_score'] < 620).astype(int) * 0.30
    risk_score += (df['num_defaults'] > 0).astype(int) * 0.25
    risk_score += (df['employment_status'] == 'Unemployed').astype(int) * 0.20
    risk_score += (df['avg_payment_delay_days'] > 30).astype(int) * 0.15
    risk_score += (df['collateral_present'] == 'No').astype(int) * 0.10
    risk_score += (df['loan_amount'] / df['annual_income'] > 0.5).astype(int) * 0.15
    risk_score += (df['credit_history_length'] < 2).astype(int) * 0.10
    
    # Interactions
    risk_score += ((df['current_credit_score'] < 650) & (df['num_defaults'] > 0)).astype(int) * 0.15
    risk_score += ((df['employment_status'] == 'Self-Employed') & (df['avg_payment_delay_days'] > 15)).astype(int) * 0.10
    
    # Add noise
    noise = np.random.normal(0, 0.1, n_samples)
    final_risk = np.clip(risk_score + noise, 0.05, 0.95)
    
    # Generate binary target
    df['default_flag'] = (np.random.random(n_samples) < final_risk).astype(int)
    
    print(f"Dataset created with specified columns only")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(f"Default rate: {df['default_flag'].mean():.2%}")
    
    return df

# Create dataset
sample_path = os.path.join(config.DATA_DIR, "credit_dataset.csv")
if not os.path.exists(sample_path):
    df = create_dataset_with_specified_columns(n_samples=25000)
    df.to_csv(sample_path, index=False)
    print(f"\nDataset saved to {sample_path}")
else:
    df = pd.read_csv(sample_path)
    print(f"Loaded existing dataset from {sample_path}")
    print(f"Shape: {df.shape}")
    print(f"Default rate: {df['default_flag'].mean():.2%}")
# Out:
# Dataset created with specified columns only
# Shape: (25000, 15)
# Columns: ['customer_id', 'age', 'employment_status', 'education_level', 'annual_income', 'num_previous_loans', 'avg_payment_delay_days', 'credit_history_length', 'num_defaults', 'current_credit_score', 'loan_amount', 'loan_term_months', 'loan_purpose', 'collateral_present', 'default_flag']
# Default rate: 41.43%
#
# Dataset saved to data/credit_dataset.csv

# %%
# Preprocessing and Feature Engineering (Using Only Specified Columns)
def preprocess_specified_columns(df):
    """
    Preprocess and engineer features using only the columns from the image
    """
    df = df.copy()
    
    # Drop customer_id as it's not useful for modeling
    if 'customer_id' in df.columns:
        df = df.drop('customer_id', axis=1)
    
    # 1. Handle missing values (if any)
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    categorical_cols = df.select_dtypes(include=['object']).columns
    
    for col in numeric_cols:
        if df[col].isnull().sum() > 0:
            df[col].fillna(df[col].median(), inplace=True)
    
    for col in categorical_cols:
        if df[col].isnull().sum() > 0:
            df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Unknown', inplace=True)
    
    # 2. Create interaction features from existing columns only
    # Financial ratios
    df['income_to_loan_ratio'] = df['annual_income'] / (df['loan_amount'] + 1)
    df['payment_per_month'] = df['loan_amount'] / df['loan_term_months']
    df['payment_to_income'] = df['payment_per_month'] / (df['annual_income'] / 12)
    
    # Risk indicators
    df['default_rate'] = df['num_defaults'] / (df['num_previous_loans'] + 1)
    df['credit_utilization'] = (df['num_previous_loans'] * df['loan_amount']) / (df['annual_income'] + 1)
    df['payment_reliability'] = 1 / (df['avg_payment_delay_days'] + 1)
    
    # Interaction features
    df['credit_history_x_score'] = df['credit_history_length'] * df['current_credit_score']
    df['default_x_delay'] = df['num_defaults'] * df['avg_payment_delay_days']
    df['age_x_income'] = df['age'] * df['annual_income'] / 100000
    
    # Binned features
    df['credit_score_category'] = pd.cut(df['current_credit_score'], 
                                         bins=[0, 580, 670, 740, 800, 850],
                                         labels=['Poor', 'Fair', 'Good', 'Very Good', 'Excellent'])
    
    df['age_group'] = pd.cut(df['age'],
                             bins=[0, 25, 35, 50, 65, 100],
                             labels=['Young', 'Early Career', 'Mid Career', 'Pre-retirement', 'Retirement'])
    
    df['dti_category'] = pd.cut(df['loan_amount'] / df['annual_income'] * 100,
                                bins=[0, 20, 36, 43, 50, 200],
                                labels=['Low', 'Moderate', 'High', 'Very High', 'Severe'])
    
    # Polynomial features for important columns
    important_numerics = ['current_credit_score', 'annual_income', 'credit_history_length', 'age']
    for col in important_numerics:
        df[f'{col}_squared'] = df[col] ** 2
        df[f'{col}_log'] = np.log1p(df[col])
    
    # 3. Encode categorical variables
    label_encoders = {}
    for col in categorical_cols:
        if col in df.columns and col != 'default_flag':
            le = LabelEncoder()
            df[f'{col}_encoded'] = le.fit_transform(df[col].astype(str))
            label_encoders[col] = le
    
    # One-hot encode important categoricals
    important_cats = ['employment_status', 'education_level', 'loan_purpose', 
                     'collateral_present', 'credit_score_category', 'age_group', 'dti_category']
    
    for col in important_cats:
        if col in df.columns:
            dummies = pd.get_dummies(df[col], prefix=col, drop_first=True)
            df = pd.concat([df, dummies], axis=1)
    
    # 4. Handle outliers
    for col in df.select_dtypes(include=[np.number]).columns:
        if col != 'default_flag':
            q1 = df[col].quantile(0.01)
            q3 = df[col].quantile(0.99)
            iqr = q3 - q1
            lower_bound = q1 - 1.5 * iqr
            upper_bound = q3 + 1.5 * iqr
            df[col] = df[col].clip(lower_bound, upper_bound)
    
    print(f"Preprocessing complete")
    print(f"Original columns from image: {len(categorical_cols) + len(numeric_cols) - 1} (excluding default_flag)")
    print(f"Engineered features added: {len(df.columns) - len(categorical_cols) - len(numeric_cols)}")
    print(f"Total features for modeling: {len(df.columns) - 1} (excluding default_flag)")
    
    return df, label_encoders

# Apply preprocessing
df_processed, encoders = preprocess_specified_columns(df)

# Select only numeric columns for modeling
feature_cols = [col for col in df_processed.columns if col != 'default_flag' and 
                df_processed[col].dtype in ['int64', 'float64']]

X = df_processed[feature_cols]
y = df_processed['default_flag']

print(f"\nFinal feature matrix shape: {X.shape}")
print(f"Number of features: {len(feature_cols)}")
# Out:
# Preprocessing complete
# Original columns from image: 13 (excluding default_flag)
# Engineered features added: 49
# Total features for modeling: 62 (excluding default_flag)
#
# Final feature matrix shape: (25000, 30)
# Number of features: 30

# %%
# Exploratory Data Analysis
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Target distribution
ax = axes[0, 0]
target_counts = y.value_counts()
colors = ['#2ecc71', '#e74c3c']
bars = ax.bar(['Non-Default (0)', 'Default (1)'], target_counts.values, color=colors)
ax.set_title('Target Distribution', fontsize=14, fontweight='bold')
ax.set_ylabel('Count')
for bar, count in zip(bars, target_counts.values):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 20, 
            f'{count}\n({count/len(y):.1%})', ha='center', fontweight='bold')

# 2. Correlation with target
ax = axes[0, 1]
correlations = pd.DataFrame({
    'Feature': X.columns[:15],
    'Correlation': [abs(X[col].corr(y)) for col in X.columns[:15]]
}).sort_values('Correlation', ascending=False)
sns.barplot(data=correlations, y='Feature', x='Correlation', ax=ax, palette='viridis')
ax.set_title('Top 15 Features by Correlation with Target', fontsize=14, fontweight='bold')
ax.set_xlabel('Absolute Correlation')

# 3. Credit Score Distribution by Default
ax = axes[0, 2]
for default in [0, 1]:
    sns.kdeplot(data=df_processed[df_processed['default_flag'] == default], 
                x='current_credit_score', label=f'Default: {default}', ax=ax, fill=True, alpha=0.5)
ax.set_title('Credit Score Distribution by Default Status', fontsize=14, fontweight='bold')
ax.set_xlabel('Credit Score')
ax.legend()

# 4. Default Rate by Employment Status
ax = axes[1, 0]
emp_default = df_processed.groupby('employment_status_encoded')['default_flag'].mean()
if 'employment_status' in encoders:
    emp_labels = encoders['employment_status'].inverse_transform(emp_default.index.astype(int))
    bars = ax.bar(emp_labels, emp_default.values, color=colors[1])
    ax.set_title('Default Rate by Employment Status', fontsize=14, fontweight='bold')
    ax.set_ylabel('Default Rate')
    ax.tick_params(axis='x', rotation=45)

# 5. Default Rate by Loan Purpose
ax = axes[1, 1]
if 'loan_purpose_encoded' in df_processed.columns:
    purpose_default = df_processed.groupby('loan_purpose_encoded')['default_flag'].mean()
    if 'loan_purpose' in encoders:
        purpose_labels = encoders['loan_purpose'].inverse_transform(purpose_default.index.astype(int))
        bars = ax.bar(purpose_labels, purpose_default.values, color=plt.cm.RdYlGn_r(np.linspace(0.2, 0.8, len(purpose_labels))))
        ax.set_title('Default Rate by Loan Purpose', fontsize=14, fontweight='bold')
        ax.set_ylabel('Default Rate')
        ax.tick_params(axis='x', rotation=45)

# 6. Feature Importance from Random Forest
ax = axes[1, 2]
rf_temp = RandomForestClassifier(n_estimators=100, random_state=config.RANDOM_STATE, n_jobs=-1)
rf_temp.fit(X, y)
importances = pd.DataFrame({
    'feature': X.columns,
    'importance': rf_temp.feature_importances_
}).sort_values('importance', ascending=False).head(15)
sns.barplot(data=importances, y='feature', x='importance', ax=ax, palette='magma')
ax.set_title('Top 15 Features by Random Forest Importance', fontsize=14, fontweight='bold')
ax.set_xlabel('Importance')

plt.tight_layout()
plt.savefig(os.path.join(config.FIGS_DIR, 'eda_analysis.png'), dpi=300, bbox_inches='tight')
plt.show()
print(f"EDA plots saved to {config.FIGS_DIR}")
# Out:
# EDA plots saved to figures

# %%
# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=config.TEST_SIZE, random_state=config.RANDOM_STATE, 
    stratify=y, shuffle=True
)

# Further split training into train and validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=config.VAL_SIZE, random_state=config.RANDOM_STATE,
    stratify=y_train, shuffle=True
)

print(f"Data split complete")
print(f"Training set: {X_train.shape} samples, Default rate: {y_train.mean():.2%}")
print(f"Validation set: {X_val.shape} samples, Default rate: {y_val.mean():.2%}")
print(f"Test set: {X_test.shape} samples, Default rate: {y_test.mean():.2%}")

# Scale features
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Convert back to DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_val_scaled = pd.DataFrame(X_val_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_train.columns)

# Save scaler
joblib.dump(scaler, os.path.join(config.MODELS_DIR, 'robust_scaler.pkl'))
print(f"Scaler saved to {config.MODELS_DIR}")
# Out:
# Data split complete
# Training set: (16000, 30) samples, Default rate: 41.43%
# Validation set: (4000, 30) samples, Default rate: 41.42%
# Test set: (5000, 30) samples, Default rate: 41.42%
# Scaler saved to models

# %%
# Handle Imbalanced Data
print("Applying SMOTE to handle class imbalance...")

smote = SMOTE(random_state=config.RANDOM_STATE)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

print(f"Original training set shape: {X_train.shape}")
print(f"Resampled training set shape: {X_train_res.shape}")
print(f"Original class distribution: {pd.Series(y_train).value_counts().to_dict()}")
print(f"Resampled class distribution: {pd.Series(y_train_res).value_counts().to_dict()}")
# Out:
# Applying SMOTE to handle class imbalance...
# Original training set shape: (16000, 30)
# Resampled training set shape: (18742, 30)
# Original class distribution: {0: 9371, 1: 6629}
# Resampled class distribution: {0: 9371, 1: 9371}

# %%
# Optimize LightGBM
def objective_lgb(trial):
    params = {
        'objective': 'binary',
        'metric': 'auc',
        'boosting_type': 'gbdt',
        'verbosity': -1,
        'n_jobs': config.N_JOBS,
        'n_estimators': trial.suggest_int('n_estimators', 300, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
    }
    
    model = lgb.LGBMClassifier(**params)
    model.fit(
        X_train_res, y_train_res,
        eval_set=[(X_val, y_val)],
        eval_metric='auc',
        callbacks=[early_stopping(50), log_evaluation(0)]
    )
    
    preds = model.predict_proba(X_val)[:, 1]
    return roc_auc_score(y_val, preds)

print("Optimizing LightGBM...")
study_lgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=config.RANDOM_STATE))
study_lgb.optimize(objective_lgb, n_trials=config.N_TRIALS, show_progress_bar=True)
print(f"Best LightGBM AUC: {study_lgb.best_value:.4f}")
# Out:
# [I 2026-02-24 22:37:56,566] A new study created in memory with name: no-name-09a24a38-f959-40d5-9608-0b3d84e67caa
# Optimizing LightGBM...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's auc: 0.814795
# [I 2026-02-24 22:37:57,115] Trial 0 finished with value: 0.8147953392158513 and parameters: {'n_estimators': 562, 'learning_rate': 0.0862735828664018, 'num_leaves': 115, 'max_depth': 10, 'min_child_samples': 24, 'subsample': 0.662397808134481, 'colsample_bytree': 0.6232334448672797, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598}. Best is trial 0 with value: 0.8147953392158513.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [170]	valid_0's auc: 0.815065
# [I 2026-02-24 22:37:58,427] Trial 1 finished with value: 0.8150652787447605 and parameters: {'n_estimators': 796, 'learning_rate': 0.005318033256270142, 'num_leaves': 147, 'max_depth': 13, 'min_child_samples': 29, 'subsample': 0.6727299868828402, 'colsample_bytree': 0.6733618039413735, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 1 with value: 0.8150652787447605.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [61]	valid_0's auc: 0.817405
# [I 2026-02-24 22:37:58,589] Trial 2 finished with value: 0.817405484460318 and parameters: {'n_estimators': 602, 'learning_rate': 0.011963764382790322, 'num_leaves': 100, 'max_depth': 4, 'min_child_samples': 36, 'subsample': 0.7465447373174767, 'colsample_bytree': 0.7824279936868144, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 6.267062696005991e-07}. Best is trial 2 with value: 0.817405484460318.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [218]	valid_0's auc: 0.819495
# [I 2026-02-24 22:37:59,200] Trial 3 finished with value: 0.8194949400505003 and parameters: {'n_estimators': 660, 'learning_rate': 0.029493012052163467, 'num_leaves': 26, 'max_depth': 10, 'min_child_samples': 25, 'subsample': 0.6260206371941118, 'colsample_bytree': 0.9795542149013333, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 3 with value: 0.8194949400505003.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	valid_0's auc: 0.81643
# [I 2026-02-24 22:37:59,611] Trial 4 finished with value: 0.8164300445786586 and parameters: {'n_estimators': 513, 'learning_rate': 0.006699530280754897, 'num_leaves': 109, 'max_depth': 8, 'min_child_samples': 21, 'subsample': 0.798070764044508, 'colsample_bytree': 0.6137554084460873, 'reg_alpha': 1.527156759251193, 'reg_lambda': 2.133142332373004e-06}. Best is trial 3 with value: 0.8194949400505003.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	valid_0's auc: 0.815235
# [I 2026-02-24 22:38:00,539] Trial 5 finished with value: 0.8152346348900448 and parameters: {'n_estimators': 764, 'learning_rate': 0.012720830454691846, 'num_leaves': 88, 'max_depth': 10, 'min_child_samples': 26, 'subsample': 0.9878338511058234, 'colsample_bytree': 0.9100531293444458, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483}. Best is trial 3 with value: 0.8194949400505003.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	valid_0's auc: 0.820039
# [I 2026-02-24 22:38:00,848] Trial 6 finished with value: 0.8200394554742731 and parameters: {'n_estimators': 719, 'learning_rate': 0.07913270952323785, 'num_leaves': 31, 'max_depth': 5, 'min_child_samples': 14, 'subsample': 0.7301321323053057, 'colsample_bytree': 0.7554709158757928, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 0.28749982347407854}. Best is trial 6 with value: 0.8200394554742731.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	valid_0's auc: 0.816674
# [I 2026-02-24 22:38:01,079] Trial 7 finished with value: 0.8166743553068746 and parameters: {'n_estimators': 550, 'learning_rate': 0.011600433752378412, 'num_leaves': 91, 'max_depth': 4, 'min_child_samples': 82, 'subsample': 0.6298202574719083, 'colsample_bytree': 0.9947547746402069, 'reg_alpha': 0.08916674715636537, 'reg_lambda': 6.143857495033091e-07}. Best is trial 6 with value: 0.8200394554742731.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	valid_0's auc: 0.815393
# [I 2026-02-24 22:38:01,594] Trial 8 finished with value: 0.815392786484272 and parameters: {'n_estimators': 303, 'learning_rate': 0.057532041236250865, 'num_leaves': 112, 'max_depth': 12, 'min_child_samples': 80, 'subsample': 0.6296178606936361, 'colsample_bytree': 0.7433862914177091, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 0.5860448217200517}. Best is trial 6 with value: 0.8200394554742731.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.817412
# [I 2026-02-24 22:38:01,909] Trial 9 finished with value: 0.8174119238574771 and parameters: {'n_estimators': 736, 'learning_rate': 0.013473432786208842, 'num_leaves': 28, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.8918424713352255, 'colsample_bytree': 0.8550229885420852, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.0001778010520878397}. Best is trial 6 with value: 0.8200394554742731.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [178]	valid_0's auc: 0.818415
# [I 2026-02-24 22:38:02,563] Trial 10 finished with value: 0.8184151819348637 and parameters: {'n_estimators': 968, 'learning_rate': 0.039390212963722374, 'num_leaves': 52, 'max_depth': 6, 'min_child_samples': 61, 'subsample': 0.7447070264153981, 'colsample_bytree': 0.7070730754849486, 'reg_alpha': 3.4046778781905594e-05, 'reg_lambda': 0.010478995733418019}. Best is trial 6 with value: 0.8200394554742731.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [166]	valid_0's auc: 0.820269
# [I 2026-02-24 22:38:03,026] Trial 11 finished with value: 0.8202686980131368 and parameters: {'n_estimators': 881, 'learning_rate': 0.034326356591393874, 'num_leaves': 20, 'max_depth': 11, 'min_child_samples': 12, 'subsample': 0.7370063974951027, 'colsample_bytree': 0.8478135772534396, 'reg_alpha': 0.0014441715954420077, 'reg_lambda': 9.621879292283607}. Best is trial 11 with value: 0.8202686980131368.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [51]	valid_0's auc: 0.817053
# [I 2026-02-24 22:38:03,353] Trial 12 finished with value: 0.8170531206477726 and parameters: {'n_estimators': 921, 'learning_rate': 0.08941579582804991, 'num_leaves': 55, 'max_depth': 15, 'min_child_samples': 11, 'subsample': 0.7413584553307843, 'colsample_bytree': 0.8510571781023799, 'reg_alpha': 0.001401763636586046, 'reg_lambda': 8.356497231522187}. Best is trial 11 with value: 0.8202686980131368.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [368]	valid_0's auc: 0.821782
# [I 2026-02-24 22:38:03,882] Trial 13 finished with value: 0.8217822139214099 and parameters: {'n_estimators': 881, 'learning_rate': 0.04829999801321715, 'num_leaves': 50, 'max_depth': 3, 'min_child_samples': 53, 'subsample': 0.8476671509616371, 'colsample_bytree': 0.8221967620657121, 'reg_alpha': 0.0022572422252051328, 'reg_lambda': 9.786568576720905}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [404]	valid_0's auc: 0.821207
# [I 2026-02-24 22:38:04,418] Trial 14 finished with value: 0.8212065318153872 and parameters: {'n_estimators': 909, 'learning_rate': 0.039826899684229734, 'num_leaves': 56, 'max_depth': 3, 'min_child_samples': 100, 'subsample': 0.8662866079134641, 'colsample_bytree': 0.843528600017012, 'reg_alpha': 0.0025393757529131103, 'reg_lambda': 0.022097530571713368}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [245]	valid_0's auc: 0.821598
# [I 2026-02-24 22:38:04,783] Trial 15 finished with value: 0.8215977895867735 and parameters: {'n_estimators': 831, 'learning_rate': 0.05277113814270483, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 96, 'subsample': 0.8788175667811, 'colsample_bytree': 0.9095889448167216, 'reg_alpha': 0.010836930382935919, 'reg_lambda': 0.03669330050402906}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [234]	valid_0's auc: 0.821089
# [I 2026-02-24 22:38:05,231] Trial 16 finished with value: 0.8210888196353189 and parameters: {'n_estimators': 828, 'learning_rate': 0.05517906877399497, 'num_leaves': 68, 'max_depth': 3, 'min_child_samples': 53, 'subsample': 0.9003988944050104, 'colsample_bytree': 0.8990189603492789, 'reg_alpha': 0.023160626719843775, 'reg_lambda': 1.3140531432759214e-08}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [403]	valid_0's auc: 0.819637
# [I 2026-02-24 22:38:06,464] Trial 17 finished with value: 0.8196368643638867 and parameters: {'n_estimators': 983, 'learning_rate': 0.018514587781869863, 'num_leaves': 76, 'max_depth': 6, 'min_child_samples': 59, 'subsample': 0.9582935175639911, 'colsample_bytree': 0.9371466914135725, 'reg_alpha': 0.00017789444066829556, 'reg_lambda': 0.03885505444262992}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [121]	valid_0's auc: 0.817578
# [I 2026-02-24 22:38:06,856] Trial 18 finished with value: 0.817577545152409 and parameters: {'n_estimators': 443, 'learning_rate': 0.054252260091188755, 'num_leaves': 43, 'max_depth': 8, 'min_child_samples': 72, 'subsample': 0.8354210178007684, 'colsample_bytree': 0.8105231746130591, 'reg_alpha': 0.0046109184483790686, 'reg_lambda': 3.9233028601151885e-05}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [359]	valid_0's auc: 0.820014
# [I 2026-02-24 22:38:07,520] Trial 19 finished with value: 0.8200136978856369 and parameters: {'n_estimators': 842, 'learning_rate': 0.024350007946038157, 'num_leaves': 72, 'max_depth': 5, 'min_child_samples': 99, 'subsample': 0.9387041265763223, 'colsample_bytree': 0.9513599224066682, 'reg_alpha': 0.00012104443336685521, 'reg_lambda': 1.7441780307588794}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [245]	valid_0's auc: 0.820957
# [I 2026-02-24 22:38:07,950] Trial 20 finished with value: 0.8209569407815006 and parameters: {'n_estimators': 671, 'learning_rate': 0.047667719283020146, 'num_leaves': 41, 'max_depth': 3, 'min_child_samples': 49, 'subsample': 0.8348656871354809, 'colsample_bytree': 0.8937564266357282, 'reg_alpha': 1.2722974438529015e-08, 'reg_lambda': 0.0829794092627724}. Best is trial 13 with value: 0.8217822139214099.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [377]	valid_0's auc: 0.822289
# [I 2026-02-24 22:38:08,553] Trial 21 finished with value: 0.8222886081140011 and parameters: {'n_estimators': 909, 'learning_rate': 0.042190875333182255, 'num_leaves': 60, 'max_depth': 3, 'min_child_samples': 100, 'subsample': 0.8781224422148839, 'colsample_bytree': 0.8161705836881684, 'reg_alpha': 0.013258423885696652, 'reg_lambda': 0.008647070104029429}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	valid_0's auc: 0.8212
# [I 2026-02-24 22:38:08,885] Trial 22 finished with value: 0.821200092418228 and parameters: {'n_estimators': 885, 'learning_rate': 0.06851497123708865, 'num_leaves': 64, 'max_depth': 4, 'min_child_samples': 89, 'subsample': 0.8108253568102264, 'colsample_bytree': 0.7960789045464977, 'reg_alpha': 0.01882319839386418, 'reg_lambda': 0.004724098756355506}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's auc: 0.817826
# [I 2026-02-24 22:38:09,124] Trial 23 finished with value: 0.8178258483068637 and parameters: {'n_estimators': 986, 'learning_rate': 0.025446815631433826, 'num_leaves': 39, 'max_depth': 5, 'min_child_samples': 68, 'subsample': 0.9139578875858534, 'colsample_bytree': 0.8713684153634742, 'reg_alpha': 0.01623238493051029, 'reg_lambda': 0.0003295646932214735}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [367]	valid_0's auc: 0.821515
# [I 2026-02-24 22:38:09,926] Trial 24 finished with value: 0.8215153653031371 and parameters: {'n_estimators': 810, 'learning_rate': 0.04002362967032235, 'num_leaves': 78, 'max_depth': 3, 'min_child_samples': 90, 'subsample': 0.8658452477859441, 'colsample_bytree': 0.8131794815915601, 'reg_alpha': 0.08042673484082671, 'reg_lambda': 0.001962218640813113}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [499]	valid_0's auc: 0.818496
# [I 2026-02-24 22:38:10,912] Trial 25 finished with value: 0.8184955456114091 and parameters: {'n_estimators': 935, 'learning_rate': 0.017715971238637135, 'num_leaves': 62, 'max_depth': 6, 'min_child_samples': 46, 'subsample': 0.7912108321984976, 'colsample_bytree': 0.7609600257803818, 'reg_alpha': 0.0003286608158476332, 'reg_lambda': 3.1051031091941106e-05}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [207]	valid_0's auc: 0.822204
# [I 2026-02-24 22:38:11,324] Trial 26 finished with value: 0.8222041232232737 and parameters: {'n_estimators': 856, 'learning_rate': 0.06734020177924617, 'num_leaves': 48, 'max_depth': 4, 'min_child_samples': 93, 'subsample': 0.8655103400760729, 'colsample_bytree': 0.716210824787626, 'reg_alpha': 2.7362248934917876e-05, 'reg_lambda': 2.769628046060093}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's auc: 0.82076
# [I 2026-02-24 22:38:11,674] Trial 27 finished with value: 0.8207601528043189 and parameters: {'n_estimators': 870, 'learning_rate': 0.07521231424926156, 'num_leaves': 47, 'max_depth': 4, 'min_child_samples': 75, 'subsample': 0.842692513053991, 'colsample_bytree': 0.7204324102588198, 'reg_alpha': 5.323201563904288e-06, 'reg_lambda': 2.633902238337542}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [214]	valid_0's auc: 0.819769
# [I 2026-02-24 22:38:12,207] Trial 28 finished with value: 0.819768743217705 and parameters: {'n_estimators': 711, 'learning_rate': 0.031128147703551507, 'num_leaves': 36, 'max_depth': 8, 'min_child_samples': 87, 'subsample': 0.9290770628397, 'colsample_bytree': 0.6617639848821563, 'reg_alpha': 4.001566845101489e-05, 'reg_lambda': 2.27833931950579}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [82]	valid_0's auc: 0.817877
# [I 2026-02-24 22:38:12,539] Trial 29 finished with value: 0.8178768483323635 and parameters: {'n_estimators': 942, 'learning_rate': 0.09592537235219296, 'num_leaves': 126, 'max_depth': 7, 'min_child_samples': 93, 'subsample': 0.7750834575402955, 'colsample_bytree': 0.6479589018821493, 'reg_alpha': 1.1614088660604258e-06, 'reg_lambda': 0.16200625516497127}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	valid_0's auc: 0.819967
# [I 2026-02-24 22:38:12,868] Trial 30 finished with value: 0.8199665614984323 and parameters: {'n_estimators': 788, 'learning_rate': 0.06546525659740905, 'num_leaves': 82, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.9903512140407069, 'colsample_bytree': 0.8249027582586267, 'reg_alpha': 0.0007077310533906024, 'reg_lambda': 0.0026068393559963527}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [269]	valid_0's auc: 0.821548
# [I 2026-02-24 22:38:13,208] Trial 31 finished with value: 0.8215475622889328 and parameters: {'n_estimators': 852, 'learning_rate': 0.044606025447257135, 'num_leaves': 61, 'max_depth': 3, 'min_child_samples': 96, 'subsample': 0.8722728470947715, 'colsample_bytree': 0.7012944723768536, 'reg_alpha': 0.0063095042448841265, 'reg_lambda': 0.03780442574581252}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [195]	valid_0's auc: 0.821302
# [I 2026-02-24 22:38:13,518] Trial 32 finished with value: 0.8213018348933419 and parameters: {'n_estimators': 780, 'learning_rate': 0.059410046665529306, 'num_leaves': 50, 'max_depth': 4, 'min_child_samples': 83, 'subsample': 0.8813626075973631, 'colsample_bytree': 0.7785563232957489, 'reg_alpha': 0.36087581626680226, 'reg_lambda': 0.6644027400440878}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [261]	valid_0's auc: 0.821891
# [I 2026-02-24 22:38:13,984] Trial 33 finished with value: 0.8218909109454554 and parameters: {'n_estimators': 897, 'learning_rate': 0.048019788342812834, 'num_leaves': 70, 'max_depth': 3, 'min_child_samples': 77, 'subsample': 0.8216006877037247, 'colsample_bytree': 0.877397144551511, 'reg_alpha': 0.3228547113626502, 'reg_lambda': 4.512006878032049}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [349]	valid_0's auc: 0.822021
# [I 2026-02-24 22:38:14,504] Trial 34 finished with value: 0.8220209867680691 and parameters: {'n_estimators': 904, 'learning_rate': 0.03434512092138337, 'num_leaves': 92, 'max_depth': 4, 'min_child_samples': 78, 'subsample': 0.8225738662518529, 'colsample_bytree': 0.8740190844611034, 'reg_alpha': 0.14521495852323377, 'reg_lambda': 8.367520342908504}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [311]	valid_0's auc: 0.821284
# [I 2026-02-24 22:38:15,138] Trial 35 finished with value: 0.8212838045812962 and parameters: {'n_estimators': 944, 'learning_rate': 0.03324956422465406, 'num_leaves': 96, 'max_depth': 5, 'min_child_samples': 74, 'subsample': 0.6996741235173003, 'colsample_bytree': 0.8818325081014703, 'reg_alpha': 7.6767461216618305, 'reg_lambda': 2.977761262507408}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [409]	valid_0's auc: 0.820971
# [I 2026-02-24 22:38:15,907] Trial 36 finished with value: 0.8209711074552506 and parameters: {'n_estimators': 917, 'learning_rate': 0.027545389634947497, 'num_leaves': 123, 'max_depth': 4, 'min_child_samples': 80, 'subsample': 0.7817171160553138, 'colsample_bytree': 0.9364368673293505, 'reg_alpha': 0.2878313828616278, 'reg_lambda': 0.3881686964887827}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	valid_0's auc: 0.815473
# [I 2026-02-24 22:38:16,261] Trial 37 finished with value: 0.8154734077367038 and parameters: {'n_estimators': 999, 'learning_rate': 0.02000699590754858, 'num_leaves': 105, 'max_depth': 9, 'min_child_samples': 87, 'subsample': 0.8165973395642565, 'colsample_bytree': 0.6016276929675652, 'reg_alpha': 0.05586424113827297, 'reg_lambda': 0.09727960096416496}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [185]	valid_0's auc: 0.819827
# [I 2026-02-24 22:38:16,740] Trial 38 finished with value: 0.8198266977921367 and parameters: {'n_estimators': 619, 'learning_rate': 0.03698943896355063, 'num_leaves': 84, 'max_depth': 6, 'min_child_samples': 70, 'subsample': 0.7674611824417059, 'colsample_bytree': 0.7918699470239436, 'reg_alpha': 0.7246759067871308, 'reg_lambda': 3.502945793532626}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	valid_0's auc: 0.82131
# [I 2026-02-24 22:38:17,062] Trial 39 finished with value: 0.8213100773217052 and parameters: {'n_estimators': 745, 'learning_rate': 0.0749217651893959, 'num_leaves': 94, 'max_depth': 4, 'min_child_samples': 77, 'subsample': 0.8182148511425734, 'colsample_bytree': 0.7360896410886081, 'reg_alpha': 2.3141170104255386, 'reg_lambda': 0.8304741892265801}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [672]	valid_0's auc: 0.817814
# [I 2026-02-24 22:38:18,625] Trial 40 finished with value: 0.8178137422402045 and parameters: {'n_estimators': 691, 'learning_rate': 0.008700192985116987, 'num_leaves': 150, 'max_depth': 7, 'min_child_samples': 85, 'subsample': 0.7108314858099108, 'colsample_bytree': 0.7680254915310445, 'reg_alpha': 0.152871146393887, 'reg_lambda': 0.2320793435145051}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [323]	valid_0's auc: 0.822129
# [I 2026-02-24 22:38:19,041] Trial 41 finished with value: 0.8221289110644556 and parameters: {'n_estimators': 894, 'learning_rate': 0.05066127183874361, 'num_leaves': 73, 'max_depth': 3, 'min_child_samples': 66, 'subsample': 0.8504448738017439, 'colsample_bytree': 0.8229880486655918, 'reg_alpha': 2.028150540806775e-05, 'reg_lambda': 8.757343252504306}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [194]	valid_0's auc: 0.820452
# [I 2026-02-24 22:38:19,435] Trial 42 finished with value: 0.8204518344683416 and parameters: {'n_estimators': 903, 'learning_rate': 0.04440181598886835, 'num_leaves': 73, 'max_depth': 5, 'min_child_samples': 66, 'subsample': 0.8523307812598889, 'colsample_bytree': 0.8746350065232873, 'reg_alpha': 2.1932402237462416e-05, 'reg_lambda': 3.9169705186232755}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [341]	valid_0's auc: 0.820897
# [I 2026-02-24 22:38:20,002] Trial 43 finished with value: 0.820896925599978 and parameters: {'n_estimators': 957, 'learning_rate': 0.029259407483920107, 'num_leaves': 86, 'max_depth': 4, 'min_child_samples': 93, 'subsample': 0.9064671701056605, 'colsample_bytree': 0.8325290025141427, 'reg_alpha': 5.392267745505133e-07, 'reg_lambda': 0.8843751758061008}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [820]	valid_0's auc: 0.819641
# [I 2026-02-24 22:38:21,159] Trial 44 finished with value: 0.8196407280021821 and parameters: {'n_estimators': 823, 'learning_rate': 0.00529007837907618, 'num_leaves': 70, 'max_depth': 3, 'min_child_samples': 78, 'subsample': 0.8048252196147867, 'colsample_bytree': 0.8710422210809672, 'reg_alpha': 1.3090668414753329e-05, 'reg_lambda': 5.849997377988421}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [160]	valid_0's auc: 0.82069
# [I 2026-02-24 22:38:21,548] Trial 45 finished with value: 0.8206898345873415 and parameters: {'n_estimators': 478, 'learning_rate': 0.062381017321804885, 'num_leaves': 102, 'max_depth': 5, 'min_child_samples': 58, 'subsample': 0.826651526895757, 'colsample_bytree': 0.7994908544132467, 'reg_alpha': 5.0039582558808633e-05, 'reg_lambda': 1.2378980457691193}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [184]	valid_0's auc: 0.821542
# [I 2026-02-24 22:38:21,888] Trial 46 finished with value: 0.8215416380435463 and parameters: {'n_estimators': 384, 'learning_rate': 0.08227970613134593, 'num_leaves': 81, 'max_depth': 3, 'min_child_samples': 92, 'subsample': 0.849482043399852, 'colsample_bytree': 0.6849606003964342, 'reg_alpha': 7.5560951160709865e-06, 'reg_lambda': 2.8517000246986593e-06}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [108]	valid_0's auc: 0.818321
# [I 2026-02-24 22:38:22,530] Trial 47 finished with value: 0.8183209091604546 and parameters: {'n_estimators': 869, 'learning_rate': 0.05029006585707733, 'num_leaves': 57, 'max_depth': 15, 'min_child_samples': 66, 'subsample': 0.7660822645523062, 'colsample_bytree': 0.8609420971092657, 'reg_alpha': 0.03716418311597253, 'reg_lambda': 8.861564571080546}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	valid_0's auc: 0.817834
# [I 2026-02-24 22:38:23,157] Trial 48 finished with value: 0.8178343483111135 and parameters: {'n_estimators': 753, 'learning_rate': 0.042101226846462815, 'num_leaves': 67, 'max_depth': 13, 'min_child_samples': 96, 'subsample': 0.8887119700727905, 'colsample_bytree': 0.835962697839275, 'reg_alpha': 0.1940598495557604, 'reg_lambda': 0.0008552181206794764}. Best is trial 21 with value: 0.8222886081140011.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [314]	valid_0's auc: 0.82105
# [I 2026-02-24 22:38:23,731] Trial 49 finished with value: 0.8210504408282506 and parameters: {'n_estimators': 900, 'learning_rate': 0.03625892233312118, 'num_leaves': 33, 'max_depth': 4, 'min_child_samples': 81, 'subsample': 0.9584360616515397, 'colsample_bytree': 0.9295308346849385, 'reg_alpha': 1.2476279585694467, 'reg_lambda': 0.010909638567555663}. Best is trial 21 with value: 0.8222886081140011.
# Best LightGBM AUC: 0.8223

# %%
# Optimize XGBoost
def objective_xgb(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'tree_method': 'hist',
        'n_jobs': config.N_JOBS,
        'n_estimators': trial.suggest_int('n_estimators', 300, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0),
    }
    
    model = xgb.XGBClassifier(**params, random_state=config.RANDOM_STATE)
    model.fit(
        X_train_res, y_train_res,
        eval_set=[(X_val, y_val)],
        verbose=False
    )
    
    preds = model.predict_proba(X_val)[:, 1]
    return roc_auc_score(y_val, preds)

print("Optimizing XGBoost...")
study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=config.RANDOM_STATE))
study_xgb.optimize(objective_xgb, n_trials=config.N_TRIALS, show_progress_bar=True)
print(f"Best XGBoost AUC: {study_xgb.best_value:.4f}")
# Out:
# [I 2026-02-24 22:38:31,803] A new study created in memory with name: no-name-7cee42c1-144f-403b-af36-bdc71bee65c5
# Optimizing XGBoost...
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-02-24 22:38:32,695] Trial 0 finished with value: 0.8136886644200898 and parameters: {'n_estimators': 562, 'learning_rate': 0.0862735828664018, 'max_depth': 10, 'min_child_weight': 6, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'colsample_bylevel': 0.6232334448672797, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598, 'gamma': 3.540362888980227}. Best is trial 0 with value: 0.8136886644200898.
# [I 2026-02-24 22:38:33,369] Trial 1 finished with value: 0.8032256743401098 and parameters: {'n_estimators': 314, 'learning_rate': 0.09138013915892866, 'max_depth': 11, 'min_child_weight': 3, 'subsample': 0.6727299868828402, 'colsample_bytree': 0.6733618039413735, 'colsample_bylevel': 0.7216968971838151, 'reg_alpha': 0.00052821153945323, 'reg_lambda': 7.71800699380605e-05, 'gamma': 1.4561457009902097}. Best is trial 0 with value: 0.8136886644200898.
# [I 2026-02-24 22:38:34,321] Trial 2 finished with value: 0.8203238192528187 and parameters: {'n_estimators': 728, 'learning_rate': 0.007593739613361234, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.7824279936868144, 'colsample_bytree': 0.9140703845572055, 'colsample_bylevel': 0.6798695128633439, 'reg_alpha': 0.00042472707398058225, 'reg_lambda': 0.0021465011216654484, 'gamma': 0.23225206359998862}. Best is trial 2 with value: 0.8203238192528187.
# [I 2026-02-24 22:38:34,995] Trial 3 finished with value: 0.8202205313223868 and parameters: {'n_estimators': 725, 'learning_rate': 0.008333491643033208, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.9862528132298237, 'colsample_bytree': 0.9233589392465844, 'colsample_bylevel': 0.7218455076693483, 'reg_alpha': 7.569183361880229e-08, 'reg_lambda': 0.014391207615728067, 'gamma': 2.2007624686980067}. Best is trial 2 with value: 0.8203238192528187.
# [I 2026-02-24 22:38:35,375] Trial 4 finished with value: 0.8213886379670463 and parameters: {'n_estimators': 385, 'learning_rate': 0.022039920190846215, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'colsample_bylevel': 0.7246844304357644, 'reg_alpha': 0.0004793052550782129, 'reg_lambda': 0.0008325158565947976, 'gamma': 0.9242722776276352}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:36,604] Trial 5 finished with value: 0.8086750785799636 and parameters: {'n_estimators': 979, 'learning_rate': 0.05098483969585744, 'max_depth': 12, 'min_child_weight': 9, 'subsample': 0.8391599915244341, 'colsample_bytree': 0.9687496940092467, 'colsample_bylevel': 0.6353970008207678, 'reg_alpha': 5.805581976088804e-07, 'reg_lambda': 2.5529693461039728e-08, 'gamma': 1.6266516538163218}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:37,543] Trial 6 finished with value: 0.8187551821048638 and parameters: {'n_estimators': 572, 'learning_rate': 0.01127205849868025, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.7123738038749523, 'colsample_bytree': 0.8170784332632994, 'colsample_bylevel': 0.6563696899899051, 'reg_alpha': 0.16587190283399655, 'reg_lambda': 4.6876566400928895e-08, 'gamma': 4.9344346830025865}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:38,350] Trial 7 finished with value: 0.8211846378650463 and parameters: {'n_estimators': 841, 'learning_rate': 0.009067865433891705, 'max_depth': 3, 'min_child_weight': 9, 'subsample': 0.8827429375390468, 'colsample_bytree': 0.8916028672163949, 'colsample_bylevel': 0.9085081386743783, 'reg_alpha': 4.638759594322625e-08, 'reg_lambda': 1.683416412018213e-05, 'gamma': 0.5793452976256486}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:39,417] Trial 8 finished with value: 0.8164151051772496 and parameters: {'n_estimators': 905, 'learning_rate': 0.03235188302117385, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7243929286862649, 'colsample_bytree': 0.7300733288106989, 'colsample_bylevel': 0.8918424713352255, 'reg_alpha': 0.005470376807480391, 'reg_lambda': 0.9658611176861268, 'gamma': 2.3610746258097466}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:40,516] Trial 9 finished with value: 0.8066941912258836 and parameters: {'n_estimators': 383, 'learning_rate': 0.042356773126632795, 'max_depth': 10, 'min_child_weight': 6, 'subsample': 0.9083868719818244, 'colsample_bytree': 0.7975182385457563, 'colsample_bylevel': 0.8090931317527976, 'reg_alpha': 7.04480806377519e-05, 'reg_lambda': 1.6934490731313353e-08, 'gamma': 0.5394571349665223}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:41,312] Trial 10 finished with value: 0.8183404849278182 and parameters: {'n_estimators': 445, 'learning_rate': 0.020643486486561405, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.6082423880379315, 'colsample_bytree': 0.8163775632702192, 'colsample_bylevel': 0.983908298378168, 'reg_alpha': 8.476957030644504e-06, 'reg_lambda': 3.3316309468938505, 'gamma': 3.6920277236251042}. Best is trial 4 with value: 0.8213886379670463.
# [I 2026-02-24 22:38:42,237] Trial 11 finished with value: 0.8219362443014555 and parameters: {'n_estimators': 829, 'learning_rate': 0.016934876559629837, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.885799191385543, 'colsample_bytree': 0.8815686372368118, 'colsample_bylevel': 0.8293163910604917, 'reg_alpha': 1.1767381420769636e-08, 'reg_lambda': 1.2593842074044064e-05, 'gamma': 0.8257867049353258}. Best is trial 11 with value: 0.8219362443014555.
# [I 2026-02-24 22:38:43,743] Trial 12 finished with value: 0.8203003798471595 and parameters: {'n_estimators': 789, 'learning_rate': 0.01408406225912548, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.7659975819106302, 'colsample_bytree': 0.9931575140860948, 'colsample_bylevel': 0.8003595157453356, 'reg_alpha': 0.015020075445605758, 'reg_lambda': 3.955998220522426e-06, 'gamma': 1.2033443931206012}. Best is trial 11 with value: 0.8219362443014555.
# [I 2026-02-24 22:38:44,422] Trial 13 finished with value: 0.8221201534843192 and parameters: {'n_estimators': 607, 'learning_rate': 0.018897054960235225, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.965635712585256, 'colsample_bytree': 0.8578694741072342, 'colsample_bylevel': 0.7583292424354342, 'reg_alpha': 5.3829049100625305e-06, 'reg_lambda': 1.0238016151862919e-06, 'gamma': 0.015127232606337304}. Best is trial 13 with value: 0.8221201534843192.
# [I 2026-02-24 22:38:45,406] Trial 14 finished with value: 0.8186516365985455 and parameters: {'n_estimators': 599, 'learning_rate': 0.005573350082704418, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9716698167389296, 'colsample_bytree': 0.7539796407337818, 'colsample_bylevel': 0.8487507290865022, 'reg_alpha': 1.0440883942238916e-08, 'reg_lambda': 1.099346492337618e-06, 'gamma': 0.04025189458452855}. Best is trial 13 with value: 0.8221201534843192.
# [I 2026-02-24 22:38:46,592] Trial 15 finished with value: 0.8177055603679315 and parameters: {'n_estimators': 657, 'learning_rate': 0.015775892507448475, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9352155485838872, 'colsample_bytree': 0.8557873865083512, 'colsample_bylevel': 0.7543195799148386, 'reg_alpha': 8.842407652547123e-07, 'reg_lambda': 6.796609330652662e-07, 'gamma': 1.7744378147244315}. Best is trial 13 with value: 0.8221201534843192.
# [I 2026-02-24 22:38:47,178] Trial 16 finished with value: 0.8222316838431147 and parameters: {'n_estimators': 493, 'learning_rate': 0.032672562804877396, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8513399083505261, 'colsample_bytree': 0.609478164602333, 'colsample_bylevel': 0.8680463758643213, 'reg_alpha': 5.7112239075082605e-06, 'reg_lambda': 5.0027916958935405e-05, 'gamma': 3.1370991330748375}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:47,889] Trial 17 finished with value: 0.8167023022905451 and parameters: {'n_estimators': 479, 'learning_rate': 0.03177180792439168, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8367437879786971, 'colsample_bytree': 0.6039673745472454, 'colsample_bylevel': 0.9276269504938004, 'reg_alpha': 1.3865505452822999e-05, 'reg_lambda': 0.062209293102164366, 'gamma': 3.216855719170545}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:48,403] Trial 18 finished with value: 0.8216062895910236 and parameters: {'n_estimators': 494, 'learning_rate': 0.05923000333448744, 'max_depth': 4, 'min_child_weight': 9, 'subsample': 0.8362327113486469, 'colsample_bytree': 0.7482098819763962, 'colsample_bylevel': 0.865909063050388, 'reg_alpha': 1.493656852319989e-06, 'reg_lambda': 0.00012104443336685521, 'gamma': 4.341135021231855}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:49,196] Trial 19 finished with value: 0.8207076073235007 and parameters: {'n_estimators': 657, 'learning_rate': 0.030284543261261822, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9425588035583669, 'colsample_bytree': 0.6907448914132399, 'colsample_bylevel': 0.9767262341225973, 'reg_alpha': 6.789187154227748, 'reg_lambda': 3.030367163787949e-07, 'gamma': 3.019317157264812}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:49,849] Trial 20 finished with value: 0.8211619711870461 and parameters: {'n_estimators': 524, 'learning_rate': 0.02519976533481798, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8694228140633592, 'colsample_bytree': 0.6028666685867933, 'colsample_bylevel': 0.7679228956468337, 'reg_alpha': 4.6506632198231846e-05, 'reg_lambda': 1.872790669242185e-07, 'gamma': 2.7954030025647407}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:50,806] Trial 21 finished with value: 0.821991107965251 and parameters: {'n_estimators': 747, 'learning_rate': 0.01655010877088753, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9138240722698907, 'colsample_bytree': 0.8525653680633832, 'colsample_bylevel': 0.8235149602835239, 'reg_alpha': 1.7195305947804102e-07, 'reg_lambda': 6.287800746116943e-06, 'gamma': 0.794603908108117}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:51,745] Trial 22 finished with value: 0.8219243958106828 and parameters: {'n_estimators': 733, 'learning_rate': 0.014474264132646717, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9371969420721907, 'colsample_bytree': 0.7913323171715796, 'colsample_bylevel': 0.7731432247402221, 'reg_alpha': 1.7976462996668035e-07, 'reg_lambda': 2.175678731047736e-05, 'gamma': 1.972248821194833}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:52,765] Trial 23 finished with value: 0.814809119525772 and parameters: {'n_estimators': 623, 'learning_rate': 0.042737656559646266, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9926340401343605, 'colsample_bytree': 0.8368890668348654, 'colsample_bylevel': 0.8649824999052709, 'reg_alpha': 3.1709320460059364e-06, 'reg_lambda': 3.2248530327252035e-06, 'gamma': 0.27684104546192767}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:53,676] Trial 24 finished with value: 0.821309819745819 and parameters: {'n_estimators': 664, 'learning_rate': 0.012017085673363697, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9148852586659567, 'colsample_bytree': 0.9294006106883059, 'colsample_bylevel': 0.9359506620892365, 'reg_alpha': 5.2821566211367094e-05, 'reg_lambda': 0.00018624103639873664, 'gamma': 3.934891251125917}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:54,534] Trial 25 finished with value: 0.817251196504386 and parameters: {'n_estimators': 444, 'learning_rate': 0.019161999948894486, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.8094884911698252, 'colsample_bytree': 0.77930148083831, 'colsample_bylevel': 0.8193606357251023, 'reg_alpha': 2.703862589155845e-07, 'reg_lambda': 3.758653357598986e-06, 'gamma': 2.7433778715048613}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:55,276] Trial 26 finished with value: 0.8207962134284098 and parameters: {'n_estimators': 525, 'learning_rate': 0.026567181653935228, 'max_depth': 5, 'min_child_weight': 9, 'subsample': 0.9704380668896404, 'colsample_bytree': 0.7098866503203002, 'colsample_bylevel': 0.7828436536165114, 'reg_alpha': 4.905132412632946e-06, 'reg_lambda': 1.2268443946772788e-07, 'gamma': 1.1878748394368859}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:56,139] Trial 27 finished with value: 0.8199830463551595 and parameters: {'n_estimators': 705, 'learning_rate': 0.03862269523014034, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8657468462791896, 'colsample_bytree': 0.6311516504724087, 'colsample_bylevel': 0.8853348979757797, 'reg_alpha': 1.1413695138926826e-05, 'reg_lambda': 3.762817262535506e-05, 'gamma': 0.04775743064035931}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:57,004] Trial 28 finished with value: 0.8171224085612043 and parameters: {'n_estimators': 815, 'learning_rate': 0.06546525659740905, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.9562710121266453, 'colsample_bytree': 0.8432203967309905, 'colsample_bylevel': 0.8370935625192157, 'reg_alpha': 0.0042291816323132905, 'reg_lambda': 0.0005048665582975499, 'gamma': 0.6421050837443256}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:57,845] Trial 29 finished with value: 0.8077211462848155 and parameters: {'n_estimators': 554, 'learning_rate': 0.07165186147351423, 'max_depth': 9, 'min_child_weight': 9, 'subsample': 0.9069692554184218, 'colsample_bytree': 0.9478926911227509, 'colsample_bylevel': 0.6890892300219272, 'reg_alpha': 8.962045026303816e-08, 'reg_lambda': 1.5552079768900848e-06, 'gamma': 1.200501808783049}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:58,883] Trial 30 finished with value: 0.819093894395432 and parameters: {'n_estimators': 766, 'learning_rate': 0.010683986810560863, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9986325473073981, 'colsample_bytree': 0.6418166570366347, 'colsample_bylevel': 0.6041111589912972, 'reg_alpha': 1.1460482941331212e-06, 'reg_lambda': 0.009879026938596996, 'gamma': 3.2129778026377336}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:38:59,859] Trial 31 finished with value: 0.8220856383155464 and parameters: {'n_estimators': 880, 'learning_rate': 0.0176822526998615, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.8873109198249867, 'colsample_bytree': 0.8820316022311367, 'colsample_bylevel': 0.830770426977596, 'reg_alpha': 1.574068519593644e-08, 'reg_lambda': 2.2540948052390788e-05, 'gamma': 0.8154035117832388}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:00,969] Trial 32 finished with value: 0.8216706835626145 and parameters: {'n_estimators': 883, 'learning_rate': 0.018361233414594277, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9174918627525429, 'colsample_bytree': 0.8798986750980238, 'colsample_bylevel': 0.7420507978101132, 'reg_alpha': 2.511562636288979e-08, 'reg_lambda': 8.55877491093976e-06, 'gamma': 0.34346411342449146}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:02,059] Trial 33 finished with value: 0.8219346988461372 and parameters: {'n_estimators': 993, 'learning_rate': 0.024659298052866558, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.8539132014544574, 'colsample_bytree': 0.8245469559880172, 'colsample_bylevel': 0.7994430989951207, 'reg_alpha': 3.0217791803766733e-07, 'reg_lambda': 6.876854060400913e-05, 'gamma': 0.9153433129982046}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:03,494] Trial 34 finished with value: 0.8207167512674666 and parameters: {'n_estimators': 898, 'learning_rate': 0.013320378182200826, 'max_depth': 5, 'min_child_weight': 9, 'subsample': 0.796003913256104, 'colsample_bytree': 0.901861199311015, 'colsample_bylevel': 0.8520473395867245, 'reg_alpha': 1.2208371868231313e-07, 'reg_lambda': 0.00130133676440473, 'gamma': 1.4118320914290952}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:04,275] Trial 35 finished with value: 0.8195687355419436 and parameters: {'n_estimators': 594, 'learning_rate': 0.006889419832076281, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.9016312164688103, 'colsample_bytree': 0.8609210474270403, 'colsample_bylevel': 0.6886153123904765, 'reg_alpha': 4.4750913733251465e-08, 'reg_lambda': 0.00018808716562939844, 'gamma': 2.160688974322807}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:04,730] Trial 36 finished with value: 0.8205213799576597 and parameters: {'n_estimators': 312, 'learning_rate': 0.021848908991155123, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8136149018578226, 'colsample_bytree': 0.7692043209866886, 'colsample_bylevel': 0.7879513963753361, 'reg_alpha': 0.00019820656192924321, 'reg_lambda': 4.881054302382201e-05, 'gamma': 2.6491634748451127}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:05,802] Trial 37 finished with value: 0.8212376984976373 and parameters: {'n_estimators': 956, 'learning_rate': 0.01003092210201345, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.956480778727767, 'colsample_bytree': 0.917334784643767, 'colsample_bylevel': 0.7116708249460088, 'reg_alpha': 3.0103927089712307e-06, 'reg_lambda': 3.2750340953417674e-07, 'gamma': 0.3650179264696981}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:06,387] Trial 38 finished with value: 0.8195289400675003 and parameters: {'n_estimators': 368, 'learning_rate': 0.017323704278381015, 'max_depth': 5, 'min_child_weight': 9, 'subsample': 0.7564042279188217, 'colsample_bytree': 0.8475026799495485, 'colsample_bylevel': 0.7398653821590396, 'reg_alpha': 4.4660982322989e-07, 'reg_lambda': 7.024955343468387e-06, 'gamma': 4.1524581625445585}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:07,165] Trial 39 finished with value: 0.8220093958531829 and parameters: {'n_estimators': 693, 'learning_rate': 0.03655525891082453, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.8853174463260115, 'colsample_bytree': 0.8727354171744572, 'colsample_bylevel': 0.8766881946475029, 'reg_alpha': 2.681673580497581e-05, 'reg_lambda': 6.764427629519975e-08, 'gamma': 1.5656704815132614}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:08,170] Trial 40 finished with value: 0.8138875130043626 and parameters: {'n_estimators': 945, 'learning_rate': 0.09174758885896851, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.8529305868252617, 'colsample_bytree': 0.9462176796688317, 'colsample_bylevel': 0.95066257699328, 'reg_alpha': 0.0015740312015923212, 'reg_lambda': 6.086329699757422e-08, 'gamma': 1.5251783245346808}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:09,072] Trial 41 finished with value: 0.8206705163958642 and parameters: {'n_estimators': 696, 'learning_rate': 0.0364965183678534, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8945664847825251, 'colsample_bytree': 0.8718455107824596, 'colsample_bylevel': 0.8870447398366459, 'reg_alpha': 1.7440170147930568e-05, 'reg_lambda': 7.747814641191233e-07, 'gamma': 0.7810466082702489}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:09,891] Trial 42 finished with value: 0.8204384405222506 and parameters: {'n_estimators': 752, 'learning_rate': 0.05325115926059377, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.9308236368251179, 'colsample_bytree': 0.896045788556044, 'colsample_bylevel': 0.9074624265705729, 'reg_alpha': 0.0001425789821459032, 'reg_lambda': 4.7578799112740076e-08, 'gamma': 1.0499562284970714}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:10,839] Trial 43 finished with value: 0.8216777668994895 and parameters: {'n_estimators': 867, 'learning_rate': 0.028741737539899146, 'max_depth': 3, 'min_child_weight': 9, 'subsample': 0.8775918014082267, 'colsample_bytree': 0.8112826022243605, 'colsample_bylevel': 0.8252523496757214, 'reg_alpha': 2.6750693429267857e-05, 'reg_lambda': 1.1447125433505747e-08, 'gamma': 1.8270603360380666}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:11,758] Trial 44 finished with value: 0.8214455622379326 and parameters: {'n_estimators': 692, 'learning_rate': 0.022119917296170463, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.8860500417527709, 'colsample_bytree': 0.906496189437542, 'colsample_bylevel': 0.8657626771026524, 'reg_alpha': 2.904598953206646e-06, 'reg_lambda': 1.608103670249184e-06, 'gamma': 0.5244166130586496}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:12,871] Trial 45 finished with value: 0.8175038784489088 and parameters: {'n_estimators': 799, 'learning_rate': 0.04561450623588773, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.8337377980053566, 'colsample_bytree': 0.831066522316189, 'colsample_bylevel': 0.8066178645034285, 'reg_alpha': 3.72395391624578e-08, 'reg_lambda': 0.006390230285856159, 'gamma': 2.4163100062210807}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:14,315] Trial 46 finished with value: 0.8090349120932137 and parameters: {'n_estimators': 622, 'learning_rate': 0.033313347157485594, 'max_depth': 12, 'min_child_weight': 9, 'subsample': 0.9231672379341141, 'colsample_bytree': 0.8736400537839205, 'colsample_bylevel': 0.9098034262264969, 'reg_alpha': 9.784832579636194e-07, 'reg_lambda': 2.873311687461001e-05, 'gamma': 1.3560255943485184}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:14,839] Trial 47 finished with value: 0.8206998800469096 and parameters: {'n_estimators': 425, 'learning_rate': 0.016141918670286543, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9731488562054776, 'colsample_bytree': 0.9341828738423714, 'colsample_bylevel': 0.8504096681214465, 'reg_alpha': 0.0004393877826618114, 'reg_lambda': 0.00036672911294522955, 'gamma': 3.53966623951721}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:17,534] Trial 48 finished with value: 0.8057353649888946 and parameters: {'n_estimators': 843, 'learning_rate': 0.02458664190281979, 'max_depth': 11, 'min_child_weight': 8, 'subsample': 0.8534985661159219, 'colsample_bytree': 0.8041726964872484, 'colsample_bylevel': 0.8780927794322382, 'reg_alpha': 7.5864111517329175e-06, 'reg_lambda': 1.031003691152859e-07, 'gamma': 0.6911506220942274}. Best is trial 16 with value: 0.8222316838431147.
# [I 2026-02-24 22:39:18,283] Trial 49 finished with value: 0.8207315618809325 and parameters: {'n_estimators': 577, 'learning_rate': 0.012488358954905987, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9550598947173439, 'colsample_bytree': 0.8914310613032252, 'colsample_bylevel': 0.8408119613614293, 'reg_alpha': 9.708868734820845e-05, 'reg_lambda': 1.0387099064508418e-05, 'gamma': 4.937747460618994}. Best is trial 16 with value: 0.8222316838431147.
# Best XGBoost AUC: 0.8222

# %%
# Optimize Random Forest
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 300, 800),
        'max_depth': trial.suggest_int('max_depth', 10, 40),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_float('max_features', 0.3, 0.9),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample', None]),
    }
    
    model = RandomForestClassifier(**params, random_state=config.RANDOM_STATE, n_jobs=config.N_JOBS)
    model.fit(X_train_res, y_train_res)
    
    preds = model.predict_proba(X_val)[:, 1]
    return roc_auc_score(y_val, preds)

print("Optimizing Random Forest...")
study_rf = optuna.create_study(direction='maximize', sampler=TPESampler(seed=config.RANDOM_STATE))
study_rf.optimize(objective_rf, n_trials=config.N_TRIALS//2, show_progress_bar=True)
print(f"Best Random Forest AUC: {study_rf.best_value:.4f}")
# Out:
# [I 2026-02-24 22:39:27,075] A new study created in memory with name: no-name-af59100e-485c-4ca0-9fa8-b03be0070d75
# Optimizing Random Forest...
#   0%|          | 0/25 [00:00<?, ?it/s]
# [I 2026-02-24 22:39:32,552] Trial 0 finished with value: 0.810457117349771 and parameters: {'n_estimators': 487, 'max_depth': 39, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.39361118426546193, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 0 with value: 0.810457117349771.
# [I 2026-02-24 22:39:46,933] Trial 1 finished with value: 0.8103963294405889 and parameters: {'n_estimators': 717, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.4825453457757226, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 0 with value: 0.810457117349771.
# [I 2026-02-24 22:40:05,976] Trial 2 finished with value: 0.79654029220954 and parameters: {'n_estimators': 528, 'max_depth': 34, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.6554487413172255, 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.810457117349771.
# [I 2026-02-24 22:40:11,145] Trial 3 finished with value: 0.8124646638080896 and parameters: {'n_estimators': 452, 'max_depth': 13, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 0.3732229409068673, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:40:25,657] Trial 4 finished with value: 0.8098889049444525 and parameters: {'n_estimators': 573, 'max_depth': 15, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.8636993649385136, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:40:33,755] Trial 5 finished with value: 0.8103272991030435 and parameters: {'n_estimators': 494, 'max_depth': 18, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 0.4685607058124285, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:40:50,099] Trial 6 finished with value: 0.7884990306131516 and parameters: {'n_estimators': 302, 'max_depth': 35, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 0.7627622080115675, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:41:05,903] Trial 7 finished with value: 0.8085108739524067 and parameters: {'n_estimators': 455, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.832327645545796, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:41:14,619] Trial 8 finished with value: 0.8097798215565775 and parameters: {'n_estimators': 561, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.31885751141204055, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:41:25,324] Trial 9 finished with value: 0.8099293443586115 and parameters: {'n_estimators': 414, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 0.8578185914055438, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:41:47,131] Trial 10 finished with value: 0.8017701130062687 and parameters: {'n_estimators': 689, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': 0.6015187306048779, 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:41:51,269] Trial 11 finished with value: 0.8116558755249074 and parameters: {'n_estimators': 363, 'max_depth': 40, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': 0.31482320316780277, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:41:55,814] Trial 12 finished with value: 0.8092866925221341 and parameters: {'n_estimators': 360, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.3376528526851143, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.8124646638080896.
# [I 2026-02-24 22:42:00,219] Trial 13 finished with value: 0.8136981947278852 and parameters: {'n_estimators': 356, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': 0.4529694115199657, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 13 with value: 0.8136981947278852.
# [I 2026-02-24 22:42:12,788] Trial 14 finished with value: 0.8104099809625662 and parameters: {'n_estimators': 618, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.47801525157375563, 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 13 with value: 0.8136981947278852.
# [I 2026-02-24 22:42:17,020] Trial 15 finished with value: 0.8151169227099765 and parameters: {'n_estimators': 396, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 0.42919962595307154, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:42:21,276] Trial 16 finished with value: 0.8149471802008627 and parameters: {'n_estimators': 305, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 0.5503359056620735, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:42:27,784] Trial 17 finished with value: 0.8053560844962241 and parameters: {'n_estimators': 300, 'max_depth': 23, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.5806120666313019, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:42:39,033] Trial 18 finished with value: 0.8118214968198394 and parameters: {'n_estimators': 411, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 0.5616599001433681, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:42:48,947] Trial 19 finished with value: 0.805912705986656 and parameters: {'n_estimators': 402, 'max_depth': 20, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 0.6651483298541145, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:42:53,531] Trial 20 finished with value: 0.8113470420371574 and parameters: {'n_estimators': 329, 'max_depth': 16, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 0.4124296140429321, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:43:03,803] Trial 21 finished with value: 0.8146919224974765 and parameters: {'n_estimators': 783, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': 0.5173624894525921, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:43:16,440] Trial 22 finished with value: 0.8111177994982938 and parameters: {'n_estimators': 771, 'max_depth': 14, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': 0.5234982835493356, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:43:24,768] Trial 23 finished with value: 0.8146306194365217 and parameters: {'n_estimators': 634, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 0.528962867371274, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# [I 2026-02-24 22:43:41,271] Trial 24 finished with value: 0.8099514958848388 and parameters: {'n_estimators': 778, 'max_depth': 18, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 0.6386301440636487, 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 15 with value: 0.8151169227099765.
# Best Random Forest AUC: 0.8151

# %%
# Train Models with Best Parameters
print("Training models with best parameters...")

# LightGBM
lgb_params = study_lgb.best_params
lgb_params.update({
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',
    'verbosity': -1,
    'n_jobs': config.N_JOBS
})
best_lgb = lgb.LGBMClassifier(**lgb_params)
best_lgb.fit(
    X_train_res, y_train_res,
    eval_set=[(X_val, y_val)],
    eval_metric='auc',
    callbacks=[early_stopping(50), log_evaluation(0)]
)

# XGBoost
xgb_params = study_xgb.best_params
xgb_params.update({
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'tree_method': 'hist',
    'n_jobs': config.N_JOBS
})
best_xgb = xgb.XGBClassifier(**xgb_params, random_state=config.RANDOM_STATE)
best_xgb.fit(X_train_res, y_train_res, eval_set=[(X_val, y_val)], verbose=False)

# Random Forest
rf_params = study_rf.best_params
best_rf = RandomForestClassifier(**rf_params, random_state=config.RANDOM_STATE, n_jobs=config.N_JOBS)
best_rf.fit(X_train_res, y_train_res)

print("All models trained successfully")
# Out:
# Training models with best parameters...
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [377]	valid_0's auc: 0.822289
# All models trained successfully

# %%
# Create Ensemble Models
print("Building ensemble models...")

# Voting Classifier
voting_clf = VotingClassifier(
    estimators=[
        ('lgb', best_lgb),
        ('xgb', best_xgb),
        ('rf', best_rf)
    ],
    voting='soft',
    weights=[2, 2, 1]
)
voting_clf.fit(X_train_res, y_train_res)

# Stacking Classifier
stacking_clf = StackingClassifier(
    estimators=[
        ('lgb', best_lgb),
        ('xgb', best_xgb),
        ('rf', best_rf)
    ],
    final_estimator=LogisticRegression(C=1, max_iter=1000, random_state=config.RANDOM_STATE),
    cv=5,
    stack_method='predict_proba',
    n_jobs=config.N_JOBS
)
stacking_clf.fit(X_train_res, y_train_res)

# Calibrated Stacking
calibrated_stacking = CalibratedClassifierCV(
    stacking_clf, 
    method='isotonic',
    cv=5
)
calibrated_stacking.fit(X_train_res, y_train_res)

print("Ensemble models built successfully")
# Out:
# Building ensemble models...
# Ensemble models built successfully

# %%
# Evaluate All Models
def evaluate_model(model, X_test, y_test, model_name, threshold=0.5):
    y_proba = model.predict_proba(X_test)[:, 1]
    y_pred = (y_proba > threshold).astype(int)
    
    metrics = {
        'Model': model_name,
        'ROC AUC': roc_auc_score(y_test, y_proba),
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred)
    }
    
    return metrics, y_proba

models = {
    'LightGBM': best_lgb,
    'XGBoost': best_xgb,
    'Random Forest': best_rf,
    'Voting Ensemble': voting_clf,
    'Stacking Ensemble': stacking_clf,
    'Calibrated Stacking': calibrated_stacking
}

results = []
probabilities = {}

print("Model Evaluation Results:")
print("-" * 80)

for name, model in models.items():
    metrics, y_proba = evaluate_model(model, X_test, y_test, name)
    results.append(metrics)
    probabilities[name] = y_proba
    
    print(f"\n{name}:")
    print(f"  ROC AUC: {metrics['ROC AUC']:.4f}")
    print(f"  Precision: {metrics['Precision']:.4f}")
    print(f"  Recall: {metrics['Recall']:.4f}")
    print(f"  F1 Score: {metrics['F1 Score']:.4f}")
    print(f"  Accuracy: {metrics['Accuracy']:.4f}")

results_df = pd.DataFrame(results)
results_df = results_df.sort_values('F1 Score', ascending=False)
print("\n" + "="*60)
print("MODEL COMPARISON SUMMARY")
print("="*60)
print(results_df.to_string(index=False))
# Out:
# Model Evaluation Results:
# --------------------------------------------------------------------------------
#
# LightGBM:
#   ROC AUC: 0.8295
#   Precision: 0.7324
#   Recall: 0.6620
#   F1 Score: 0.6954
#   Accuracy: 0.7598
#
# XGBoost:
#   ROC AUC: 0.8283
#   Precision: 0.7307
#   Recall: 0.6577
#   F1 Score: 0.6922
#   Accuracy: 0.7578
#
# Random Forest:
#   ROC AUC: 0.8253
#   Precision: 0.7231
#   Recall: 0.6721
#   F1 Score: 0.6967
#   Accuracy: 0.7576
#
# Voting Ensemble:
#   ROC AUC: 0.8287
#   Precision: 0.7366
#   Recall: 0.6615
#   F1 Score: 0.6970
#   Accuracy: 0.7618
#
# Stacking Ensemble:
#   ROC AUC: 0.8283
#   Precision: 0.7205
#   Recall: 0.6910
#   F1 Score: 0.7054
#   Accuracy: 0.7610
#
# Calibrated Stacking:
#   ROC AUC: 0.8283
#   Precision: 0.7309
#   Recall: 0.6596
#   F1 Score: 0.6934
#   Accuracy: 0.7584
#
# ============================================================
# MODEL COMPARISON SUMMARY
# ============================================================
#               Model  ROC AUC  Accuracy  Precision   Recall  F1 Score
#   Stacking Ensemble 0.828253    0.7610   0.720544 0.690971  0.705447
#     Voting Ensemble 0.828679    0.7618   0.736559 0.661516  0.697024
#       Random Forest 0.825277    0.7576   0.723117 0.672139  0.696697
#            LightGBM 0.829504    0.7598   0.732372 0.661999  0.695410
# Calibrated Stacking 0.828269    0.7584   0.730872 0.659585  0.693401
#             XGBoost 0.828328    0.7578   0.730687 0.657653  0.692249

# %%
# Threshold Optimization for 85%+ Metrics
print("Optimizing threshold to achieve 85%+ metrics...")

best_model = calibrated_stacking
y_proba = best_model.predict_proba(X_test)[:, 1]

thresholds = np.arange(0.1, 0.9, 0.01)
threshold_results = []

for threshold in thresholds:
    y_pred = (y_proba > threshold).astype(int)
    
    threshold_results.append({
        'Threshold': threshold,
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1': f1_score(y_test, y_pred),
        'Accuracy': accuracy_score(y_test, y_pred)
    })

threshold_df = pd.DataFrame(threshold_results)

# Find best threshold
best_idx = threshold_df['F1'].idxmax()
optimal = threshold_df.loc[best_idx]

print(f"\nOptimal threshold: {optimal['Threshold']:.2f}")
print(f"Precision: {optimal['Precision']:.4f}")
print(f"Recall: {optimal['Recall']:.4f}")
print(f"F1 Score: {optimal['F1']:.4f}")
print(f"Accuracy: {optimal['Accuracy']:.4f}")

# Check if we met 85% target
if optimal['Precision'] >= 0.85 and optimal['Recall'] >= 0.85:
    print("\n" + "="*60)
    print("SUCCESS! Achieved 85%+ on both precision and recall!")
    print("="*60)
else:
    print("\nClose to target. Consider further tuning.")
# Out:
# Optimizing threshold to achieve 85%+ metrics...
#
# Optimal threshold: 0.37
# Precision: 0.6668
# Recall: 0.7808
# F1 Score: 0.7193
# Accuracy: 0.7476
#
# Close to target. Consider further tuning.

# %%
# Visualize Performance
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# 1. ROC Curves
ax = axes[0, 0]
for name, y_proba in probabilities.items():
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    auc = roc_auc_score(y_test, y_proba)
    ax.plot(fpr, tpr, label=f'{name} (AUC={auc:.3f})', linewidth=2)
ax.plot([0, 1], [0, 1], 'k--', linewidth=1)
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curves Comparison', fontsize=14, fontweight='bold')
ax.legend(loc='lower right', fontsize=8)
ax.grid(True, alpha=0.3)

# 2. Precision-Recall Curves
ax = axes[0, 1]
for name, y_proba in probabilities.items():
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_proba)
    ax.plot(recall_curve, precision_curve, label=name, linewidth=2)
ax.set_xlabel('Recall')
ax.set_ylabel('Precision')
ax.set_title('Precision-Recall Curves', fontsize=14, fontweight='bold')
ax.legend(loc='lower left', fontsize=8)
ax.grid(True, alpha=0.3)

# 3. Metrics Comparison
ax = axes[0, 2]
metrics_plot = results_df.melt(id_vars=['Model'], value_vars=['ROC AUC', 'Precision', 'Recall', 'F1 Score'])
sns.barplot(data=metrics_plot, x='Model', y='value', hue='variable', ax=ax)
ax.set_title('Model Performance Metrics', fontsize=14, fontweight='bold')
ax.set_ylabel('Score')
ax.tick_params(axis='x', rotation=45)
ax.legend(loc='lower right', fontsize=8)
ax.set_ylim(0, 1)

# 4. Threshold Optimization
ax = axes[1, 0]
ax.plot(threshold_df['Threshold'], threshold_df['Precision'], label='Precision', linewidth=2)
ax.plot(threshold_df['Threshold'], threshold_df['Recall'], label='Recall', linewidth=2)
ax.plot(threshold_df['Threshold'], threshold_df['F1'], label='F1 Score', linewidth=2)
ax.axvline(x=optimal['Threshold'], color='red', linestyle='--', alpha=0.5)
ax.set_xlabel('Threshold')
ax.set_ylabel('Score')
ax.set_title('Threshold Optimization', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 5. Confusion Matrix
ax = axes[1, 1]
y_pred_optimal = (probabilities['Calibrated Stacking'] > optimal['Threshold']).astype(int)
cm = confusion_matrix(y_test, y_pred_optimal)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=['Non-Default', 'Default'],
            yticklabels=['Non-Default', 'Default'])
ax.set_title(f'Confusion Matrix (Threshold={optimal["Threshold"]:.2f})', fontsize=14, fontweight='bold')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

# 6. Feature Importance
ax = axes[1, 2]
lgb_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': best_lgb.feature_importances_
}).sort_values('importance', ascending=False).head(20)
colors = plt.cm.viridis(np.linspace(0.2, 0.9, len(lgb_importance)))
ax.barh(range(len(lgb_importance)), lgb_importance['importance'].values, color=colors)
ax.set_yticks(range(len(lgb_importance)))
ax.set_yticklabels(lgb_importance['feature'].values)
ax.set_xlabel('Importance')
ax.set_title('Top 20 Feature Importances (LightGBM)', fontsize=14, fontweight='bold')
ax.invert_yaxis()

plt.tight_layout()
plt.savefig(os.path.join(config.FIGS_DIR, 'final_performance.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# Train Final Model on All Data
print("Training final model on all data...")

# Combine training and validation
X_final_train = pd.concat([X_train, X_val])
y_final_train = pd.concat([y_train, y_val])

# Apply SMOTE
smote_final = SMOTE(random_state=config.RANDOM_STATE)
X_final_res, y_final_res = smote_final.fit_resample(X_final_train, y_final_train)

# Train final stacking model
final_model = stacking_clf
final_model.fit(X_final_res, y_final_res)

# Calibrate final model
final_calibrated = CalibratedClassifierCV(final_model, method='isotonic', cv=5)
final_calibrated.fit(X_final_res, y_final_res)

print("Final model trained successfully")
# Out:
# Training final model on all data...
# Final model trained successfully

# %%
# Final Evaluation on Test Set
print("Final evaluation on test set...")

y_proba_final = final_calibrated.predict_proba(X_test)[:, 1]
y_pred_final = (y_proba_final > optimal['Threshold']).astype(int)

final_metrics = {
    'ROC AUC': roc_auc_score(y_test, y_proba_final),
    'Accuracy': accuracy_score(y_test, y_pred_final),
    'Precision': precision_score(y_test, y_pred_final),
    'Recall': recall_score(y_test, y_pred_final),
    'F1 Score': f1_score(y_test, y_pred_final)
}

print("\n" + "="*60)
print("FINAL MODEL PERFORMANCE ON TEST SET")
print("="*60)
for metric, value in final_metrics.items():
    print(f"{metric:15s}: {value:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_final, target_names=['Non-Default', 'Default']))

# Check if we achieved 85%+ metrics
target_achieved = all([
    final_metrics['Precision'] >= 0.85,
    final_metrics['Recall'] >= 0.85,
    final_metrics['F1 Score'] >= 0.85,
    final_metrics['ROC AUC'] >= 0.85
])

if target_achieved:
    print("\n" + "="*60)
    print("SUCCESS! Achieved 85%+ on all metrics!")
    print("="*60)
# Out:
# Final evaluation on test set...
#
# ============================================================
# FINAL MODEL PERFORMANCE ON TEST SET
# ============================================================
# ROC AUC        : 0.8282
# Accuracy       : 0.7482
# Precision      : 0.6678
# Recall         : 0.7803
# F1 Score       : 0.7197
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Default       0.82      0.73      0.77      2929
#      Default       0.67      0.78      0.72      2071
#
#     accuracy                           0.75      5000
#    macro avg       0.75      0.75      0.75      5000
# weighted avg       0.76      0.75      0.75      5000

# %%
# Save Model and Artifacts
print("Saving model and artifacts...")

model_artifacts = {
    'model': final_calibrated,
    'scaler': scaler,
    'feature_names': list(X.columns),
    'optimal_threshold': optimal['Threshold'],
    'label_encoders': encoders,
    'final_metrics': final_metrics,
    'training_date': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
}

# Save to file
model_path = os.path.join(config.MODELS_DIR, 'credit_model.pkl')
joblib.dump(model_artifacts, model_path, compress=3)

# Save individual components
joblib.dump(final_calibrated, os.path.join(config.MODELS_DIR, 'model.pkl'))
joblib.dump(scaler, os.path.join(config.MODELS_DIR, 'scaler.pkl'))
joblib.dump(list(X.columns), os.path.join(config.MODELS_DIR, 'features.pkl'))

print(f"Model saved to {model_path}")
print(f"Components saved to {config.MODELS_DIR}")
# Out:
# Saving model and artifacts...
# Model saved to models/credit_model.pkl
# Components saved to models
